# %%
import pandas as pd
from pymongo import MongoClient
client = MongoClient()

# %%
user_etl = client.amanzi_etl.user_etl

# %%
for a in user_etl.find({},{'followers_ids':0, 'common_followers':0}).limit(10):
    print a
# Out:
# {u'lang': u'en', u'user_id': 832677980, u'description': u'I Rap, plan events, DJ, and fund raise\r\nFilmfighters2011@gmail.com or Text 415-286-4852 Lex Luther', u'friends_count': 1753, u'date_modified': datetime.datetime(2015, 2, 2, 16, 5, 17, 362000), u'user_id_str': u'832677980', u'name': u'Lex Luther', u'followers_count': 326, u'protected': False, u'location': u'San Francisco', u'statuses_count': 169, u'geo_enabled': True, u'_id': ObjectId('54cfe68d6c1329037b759f77'), u'listed_count': 1, u'screen_name': u'TC92100971'}
# {u'lang': u'en', u'user_id': 2780783861.0, u'description': u'', u'friends_count': 286, u'date_modified': datetime.datetime(2015, 2, 2, 16, 5, 17, 362000), u'user_id_str': u'2780783861', u'name': u'Keysha Freeman ', u'followers_count': 90, u'protected': False, u'location': u'Natchez ms', u'statuses_count': 42, u'geo_enabled': False, u'_id': ObjectId('54cfe68d6c1329037b759f78'), u'listed_count': 0, u'screen_name': u'lilmamabaaaddd'}
# ...

# %%
cursor = user_etl.find({},{'followers_ids':0})
df =  pd.DataFrame(list(cursor))

# %%
df.head()
# Out:
#                         _id  \
# 0  54cfe68d6c1329037b759f77
# 1  54cfe68d6c1329037b759f78
# 2  54cfe68d6c1329037b759f79
# 3  54cfe68d6c1329037b759f7c
# 4  54cfe68d6c1329037b759f81
#
#                                     common_followers  \
# 0  [189063883, 2531529606.0, 111700360, 260590025...
# 1                             [827697540, 179852903]
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                date_modified  \
# 0 2015-02-02 16:05:17.362000
# 1 2015-02-02 16:05:17.362000
# 2 2015-02-02 16:05:17.362000
# 3 2015-02-02 16:05:17.362000
# 4 2015-02-02 16:05:17.363000
#
#                                          description  followers_count  \
# 0  I Rap, plan events, DJ, and fund raise\r\nFilm...              326
# 1                                                                  90
# ...

# %%
df['common_followers_count'] = df['common_followers'].apply(lambda x: len(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1760 entries, 0 to 1759
# Data columns (total 19 columns):
# _id                       1760 non-null object
# common_followers          1760 non-null object
# date_modified             1760 non-null datetime64[ns]
# description               1760 non-null object
# followers_count           1760 non-null int64
# friends_count             1760 non-null int64
# geo_enabled               1760 non-null bool
# lang                      1760 non-null object
# listed_count              1760 non-null int64
# location                  1760 non-null object
# name                      1760 non-null object
# protected                 1760 non-null bool
# screen_name               1760 non-null object
# statuses_count            1760 non-null int64
# suspect_profile           50 non-null object
# time_zone                 895 non-null object
# user_id                   1760 non-null float64
# user_id_str               1760 non-null object
# ...

# %%
df.describe()
# Out:
#        followers_count   friends_count geo_enabled  listed_count   protected  \
# count      1760.000000     1760.000000        1760   1760.000000        1760
# mean      14777.652273    10564.664205   0.3465909     36.439773  0.05113636
# std       79552.519128    44726.311683   0.4760193    160.423274   0.2203384
# min           0.000000        1.000000       False      0.000000       False
# 25%         146.750000      461.750000           0      0.000000           0
# 50%         491.500000     1160.500000           0      1.000000           0
# 75%        2477.500000     2010.250000           1      7.000000           0
# max     2157326.000000  1358859.000000        True   2578.000000        True
#
#        statuses_count       user_id  common_followers_count
# count     1760.000000  1.760000e+03             1760.000000
# mean      9666.568750  1.330264e+09               11.405682
# std      42137.934309  1.079217e+09               22.444250
# ...

# %%
pd.DataFrame.hist(df[df.followers_count < 2000], column='followers_count',figsize=(8,5), bins=100, alpha=0.5) 
plt.title('Distribution of Hard Hittin Followers with less then 2000 followers\n')
